# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamAshbee/minigan-catalyst/blob/master/LSTMTesting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://github.com/bhpfelix/PyTorch-Time-Series-Classification-Benchmarks/blob/master/MaterialRecognitionModels.ipynb
import shutil, os, csv, itertools, glob

import math
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim

from sklearn.metrics import confusion_matrix

import pandas as pd
import pickle as pk

cuda = torch.cuda.is_available()

# %%
## Multilayer LSTM based classifier taking in 200 dimensional fixed time series inputs
class LSTMClassifier(nn.Module):

    def __init__(self, in_dim, hidden_dim, num_layers, dropout, bidirectional, num_classes, batch_size):
        super(LSTMClassifier, self).__init__()
        self.arch = 'lstm'
        self.hidden_dim = hidden_dim
        self.batch_size = batch_size
        self.num_dir = 2 if bidirectional else 1
        self.num_layers = num_layers

        self.lstm = nn.LSTM(
                input_size=in_dim,
                hidden_size=hidden_dim,
                num_layers=num_layers,
                dropout=dropout,
                bidirectional=bidirectional
            )

        self.hidden2label = nn.Sequential(
            nn.Linear(hidden_dim*self.num_dir, hidden_dim),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(hidden_dim, num_classes),
            nn.Sigmoid()
        )

        # self.hidden = self.init_hidden()

    def init_hidden(self):
        if cuda:
            h0 = Variable(torch.zeros(self.num_layers*self.num_dir, self.batch_size, self.hidden_dim).cuda())
            c0 = Variable(torch.zeros(self.num_layers*self.num_dir, self.batch_size, self.hidden_dim).cuda())
        else:
            h0 = Variable(torch.zeros(self.num_layers*self.num_dir, self.batch_size, self.hidden_dim))
            c0 = Variable(torch.zeros(self.num_layers*self.num_dir, self.batch_size, self.hidden_dim))
        return (h0, c0)

    def forward(self, x): # x is (batch_size, 1, 200), permute to (200, batch_size, 1)
        x = x.permute(2, 0, 1)
        # See: https://discuss.pytorch.org/t/solved-why-we-need-to-detach-variable-which-contains-hidden-representation/1426/2
        lstm_out, (h, c) = self.lstm(x, self.init_hidden())
        y  = self.hidden2label(lstm_out[-1])
        return y

# %%
def get_models(): # tuples of (batch_size, model)
    return [
         LSTMClassifier(
            in_dim=2,
            hidden_dim=120,
            num_layers=3,
            dropout=0.8,
            bidirectional=True,
            num_classes=1,#bce loss for discriminator
            batch_size=256
        )
    ]

# %%
model = get_models()[0]

# %%
model
# Out:
# LSTMClassifier(
#   (lstm): LSTM(2, 120, num_layers=3, dropout=0.8, bidirectional=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=240, out_features=120, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=120, out_features=120, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=120, out_features=1, bias=True)
#     (7): Sigmoid()
#   )
# )

# %%
x = torch.ones(256,2,200).float().cuda()
model = model.cuda()

# %%
model(x).shape
# Out:
# torch.Size([256, 1])

# %%
# Dummy Dataset for testing purpose only
class DummyDataset(Dataset):
    """Time Series dataset."""

    def __init__(self, numclasses=15):
        self.numclasses = numclasses

    def __len__(self):
        return 512

    def __getitem__(self, idx):
        data = None
        y = None
        if torch.rand(1)[0] > .5:
          data = torch.ones(2,200).float()
          y = float(1)
        else:
          data = torch.zeros(2,200).float()
          y = float(0)
          
        return data, y

# %%
data = DummyDataset(numclasses=2)
D = model.cuda()
train_loader = torch.utils.data.DataLoader(
    data,
    batch_size=256, shuffle=True)
D_optimizer = optim.Adam(D.parameters(), lr=.0001, betas=(0.5, 0.999))

# %%
bce = torch.nn.BCELoss()

# %%
for epoch in range(100):
  for x_, y_ in train_loader:
    y_ = y_.unsqueeze(dim = 1).float().cuda()
    x_ = x_.cuda()

    D_result = D(x_)
    #print(D_result)
    #break
    #print(D_result)
    D_train_loss = bce(D_result, y_)
    print('D_train_loss', D_train_loss)
    D_train_loss.backward()
    D_optimizer.step()
# Out:
# D_train_loss tensor(0.6920, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6941, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6932, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6932, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6951, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6928, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6905, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6927, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6949, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6925, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6911, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6916, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6897, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6908, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6947, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6928, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6882, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6909, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6865, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6898, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6889, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6874, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6853, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6867, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6844, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6782, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6807, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6761, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6712, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6713, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6658, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6616, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6590, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6523, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6404, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6416, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6344, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6222, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6015, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.5857, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.5691, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.5544, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.5336, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.5075, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.4863, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.4851, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.4288, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.4105, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.4156, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.3931, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.3612, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.3488, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.3254, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.3152, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.2858, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.2931, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.2630, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.2266, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.2281, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.2179, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1972, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1742, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1608, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1591, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1343, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1405, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1156, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1202, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1018, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1049, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0758, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0676, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0678, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0621, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0522, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0493, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0421, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0349, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0322, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0277, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0294, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0214, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0199, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0207, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0148, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0130, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0119, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0127, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0088, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0069, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0070, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0057, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0050, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0049, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0042, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0031, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0028, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0033, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0021, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0022, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0016, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0016, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0015, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0008, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0010, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0008, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0006, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0006, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0005, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0005, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0005, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0003, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0004, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0004, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0002, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0002, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0002, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0002, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0001, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0001, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(6.6354e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(3.8815e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0003, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(3.0782e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(4.5515e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(9.9549e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(7.5298e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(4.1324e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.2557e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.8609e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.6613e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.5177e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.2358e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(9.6506e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.6760e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(9.8789e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.9527e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.9925e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(3.1797e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.7310e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(5.2071e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.8936e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(4.6347e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(4.1042e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.0399e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(3.2184e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(7.8116e-07, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.3700e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.5382e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(8.7593e-07, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(5.1107e-07, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(4.9105e-07, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(5.9489e-07, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.5426e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(3.7858e-07, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.1630e-07, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(3.2457e-07, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.4913e-07, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.1188e-07, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(5.6345e-08, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.2363e-07, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(4.1677e-08, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.7067e-07, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.3434e-07, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(8.1258e-08, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.7346e-07, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(4.3539e-08, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(7.0781e-08, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.6531e-08, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(4.4005e-08, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.4203e-08, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.8405e-08, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(8.1491e-08, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.7229e-08, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(3.1432e-08, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(5.6578e-08, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(3.4925e-09, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(7.6834e-09, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.3283e-09, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(9.7789e-09, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(6.9849e-10, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.2119e-08, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(5.8208e-09, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(3.8417e-08, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(9.7557e-08, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.3970e-09, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(6.9849e-10, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(4.6566e-10, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.3283e-10, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.1642e-09, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.3283e-10, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(6.9849e-10, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(4.6566e-10, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.3970e-09, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0., device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(4.6566e-10, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0., device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0., device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.3283e-10, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0., device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)

# %%
data1 = torch.ones(1,2,200).float()
y1 = torch.ones(1,1)
data0 = torch.zeros(1,2,200).float()
y0 = torch.zeros(1,1)

# %%
for x, y in train_loader:
  x = x.cuda()
  print(torch.sum(model(x)>.5))
  print(torch.sum(y))
# Out:
# tensor(126, device='cuda:0')
# tensor(126., dtype=torch.float64)
# tensor(133, device='cuda:0')
# tensor(133., dtype=torch.float64)

# %%
# Dummy Dataset for testing purpose only
class DummyDataset2(Dataset):
    """Time Series dataset."""

    def __len__(self):
        return 512

    def __getitem__(self, idx):
        data = None
        y = None
        ind = [x for x in range(200)]
        ind = torch.tensor(ind).float()
        if torch.rand(1)[0] > .5:
          data = torch.ones(2,200).float()
          data[0,:] = torch.sin(ind) +torch.rand(1)[0]
          data[1,:] = torch.cos(ind) +torch.rand(1)[0]
          y = float(1)
        else:
          data = torch.ones(2,200).float()
          
          data[0,:] = torch.sin(ind*2.0) +torch.rand(1)[0] 
          data[1,:] = torch.cos(ind*2.0) +torch.rand(1)[0] 
          y = float(0)
          
        return data, y

# %%
data = DummyDataset2()
D = get_models()[0].cuda()
train_loader = torch.utils.data.DataLoader(
    data,
    batch_size=256, shuffle=True)
D_optimizer = optim.Adam(D.parameters(), lr=.0001, betas=(0.5, 0.999))

# %%
for epoch in range(100):
  for x_, y_ in train_loader:
    y_ = y_.unsqueeze(dim = 1).float().cuda()
    x_ = x_.cuda()

    D_result = D(x_)
    #print(D_result)
    #break
    #print(D_result)
    D_train_loss = bce(D_result, y_)
    print('D_train_loss', D_train_loss)
    D_train_loss.backward()
    D_optimizer.step()
# Out:
# D_train_loss tensor(0.6925, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6944, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6929, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6936, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6946, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6940, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6941, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6967, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6937, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6933, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6938, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6941, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6925, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6921, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6934, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6937, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6941, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6934, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6927, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6922, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6921, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6918, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6940, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6929, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6891, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6929, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6937, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6925, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6937, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6918, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6925, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6890, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6925, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6903, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6895, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6918, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6913, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6962, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6916, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6875, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6866, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6917, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6918, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6874, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6873, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6897, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6874, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6858, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6852, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6854, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6855, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6819, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6806, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6805, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6781, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6774, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6777, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6749, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6721, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6691, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6683, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6685, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6551, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6494, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6547, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6403, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6466, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6453, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6292, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6168, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6122, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.6106, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.5878, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.5736, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.5555, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.5653, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.5289, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.5173, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.4954, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.4683, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.4514, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.4303, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.4210, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.4105, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.3689, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.3302, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.3285, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.3334, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.2875, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.2571, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1849, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.2162, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.2370, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.2330, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1906, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1526, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1191, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1115, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1116, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1177, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1663, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1820, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1756, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.1517, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0653, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0600, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0501, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0398, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0404, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0331, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0374, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0343, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0304, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0285, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0330, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0340, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0410, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0526, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0267, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0251, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0137, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0131, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0104, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0067, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0065, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0052, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0035, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0038, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0029, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0024, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0028, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0022, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0023, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0022, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0011, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0012, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0013, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0008, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0007, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0007, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0005, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0006, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0005, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0002, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0004, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0003, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0001, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0002, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0001, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0001, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0002, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(9.6654e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(4.8313e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(3.6509e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(9.3105e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(3.8837e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(6.0934e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0002, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0190, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.5474e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0003, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.7551, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.5428e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(7.3609e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(3.5534e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.2177e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.9646e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(3.8377e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.6147e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(8.9805e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(3.0577e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(7.5092e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(3.0347e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(3.9557e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.0904e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(5.5729e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(8.5782e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.0982e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.5733e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.9143e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.4159e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0020, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(4.2487e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(1.0625e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0001, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0227, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0317, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0009, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0166, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0321, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0203, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0028, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0767, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.3620e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(0.0530, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(7.6720e-07, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.3662e-05, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.8980e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# D_train_loss tensor(2.4865e-06, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)

# %%
#https://github.com/bhpfelix/PyTorch-Time-Series-Classification-Benchmarks/blob/master/MaterialRecognitionModels.ipynb
